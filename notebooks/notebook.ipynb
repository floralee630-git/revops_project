# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.learning
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8391120706903926>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE SCHEMA IF NOT EXISTS workspace.learning\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:214, in SqlMagic.sql(self, line, cell)
#     207 except BaseException as e:
#     208     self.driver_activity_logger.logExecuteCommandEvent(
#     209         "SQL_MAGIC_PY4J_FAILED",
#     210         exceptionClassName=e.__class__.__name__,
#     211         sqlState=safe_call(e, "getSqlState"),
#     212         errorClass=safe_call(e, "getCondition"),
#     213     )
# --> 214     raise e
#     216 self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_SUCCEEDED")
#     217 return result
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:206, in SqlMagic.sql(self, line, cell)
#     204         query_text = sub_query.query()
#     205         sql_directive = self._execution_lifecycle_client.getSqlDirective(query_text)
# --> 206         result = self._handle_sql_directive(sql_directive, i == number_of_sub_queries - 1)
#     207 except BaseException as e:
#     208     self.driver_activity_logger.logExecuteCommandEvent(
#     209         "SQL_MAGIC_PY4J_FAILED",
#     210         exceptionClassName=e.__class__.__name__,
#     211         sqlState=safe_call(e, "getSqlState"),
#     212         errorClass=safe_call(e, "getCondition"),
#     213     )
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:226, in SqlMagic._handle_sql_directive(self, sql_directive, is_last_query)
#     224     query = sql_directive.sql()
#     225     self._register_udf_if_needed(query)
# --> 226     df = self._get_query_request_result(query)
#     227 elif directive_name in ("CreateView", "DropTable", "AlterTable", "CreateTable"):
#     228     result_df = self._get_query_request_result(sql_directive.sql())
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:169, in SqlMagic._get_query_request_result(self, query)
#     167 if len(widget_bindings := self._widget_cache.values) > 0:
#     168     self.driver_activity_logger.logExecuteCommandEvent("PARAM_SYNTAX_USAGE")
# --> 169 df = self.spark.sql(query, widget_bindings)
#     170 return df
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/session.py:901, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     898         _views.append(SubqueryAlias(df._plan, name))
#     900 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 901 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     902 if "sql_command_result" in properties:
#     903     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1538, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
#    1536     req.user_context.user_id = self._user_id
#    1537 self._set_command_in_plan(req.plan, command)
# -> 1538 data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
#    1539     req, observations or {}, extra_request_metadata
#    1540 )
#    1541 # Create a query execution object.
#    1542 ei = ExecutionInfo(metrics, observed_metrics)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2086, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
#    2083 properties: Dict[str, Any] = {}
#    2085 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 2086     for response in self._execute_and_fetch_as_iterator(
#    2087         req, observations, extra_request_metadata or [], progress=progress
#    2088     ):
#    2089         if isinstance(response, StructType):
#    2090             schema = response
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2062, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
#    2060     raise kb
#    2061 except Exception as error:
# -> 2062     self._handle_error(error)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2380, in SparkConnectClient._handle_error(self, error)
#    2378     self.thread_local.inside_error_handling = True
#    2379     if isinstance(error, grpc.RpcError):
# -> 2380         self._handle_rpc_error(error)
#    2381     raise error
#    2382 finally:
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2458, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2454             logger.debug(f"Received ErrorInfo: {info}")
#    2456             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
# -> 2458             raise convert_exception(
#    2459                 info,
#    2460                 status.message,
#    2461                 self._fetch_enriched_error(info),
#    2462                 self._display_server_stack_trace(),
#    2463                 status_code,
#    2464             ) from None
#    2466     raise SparkConnectGrpcException(
#    2467         message=status.message,
#    2468         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
#    2469         grpc_status_code=status_code,
#    2470     ) from None
#    2471 else:
#
# AnalysisException: [NO_SUCH_CATALOG_EXCEPTION] Catalog 'workspace' was not found. Please verify the catalog name and then retry the query or command again. SQLSTATE: 42704
#
# JVM stacktrace:
# org.apache.spark.sql.catalyst.analysis.NoSuchCatalogException
# 	at com.databricks.sql.managedcatalog.client.ManagedCatalogClientImpl.$anonfun$getCatalogProto$1(ManagedCatalogClientImpl.scala:724)
# 	at com.databricks.sql.managedcatalog.client.ManagedCatalogClientImpl.$anonfun$recordAndWrapExceptionBase$2(ManagedCatalogClientImpl.scala:8525)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:146)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at com.databricks.sql.managedcatalog.client.ManagedCatalogClientImpl.$anonfun$recordAndWrapExceptionBase$1(ManagedCatalogClientImpl.scala:8524)
# 	at com.databricks.sql.managedcatalog.client.ErrorDetailsHandlerImpl.wrapServiceException(ErrorDetailsHandler.scala:96)
# 	at com.databricks.sql.managedcatalog.client.ErrorDetailsHandlerImpl.wrapServiceException$(ErrorDetailsHandler.scala:88)
# 	at com.databricks.managedcatalog.ManagedCatalogClientImpl.wrapServiceException(ManagedCatalogClientImpl.scala:44)
# 	at com.databricks.sql.managedcatalog.client.ManagedCatalogClientImpl.recordAndWrapExceptionBase(ManagedCatalogClientImpl.scala:8503)
# 	at com.databricks.sql.managedcatalog.client.ManagedCatalogClientImpl.recordAndWrapExceptionWithoutPerApiMetric(ManagedCatalogClientImpl.scala:8432)
# 	at com.databricks.sql.managedcatalog.client.ManagedCatalogClientImpl.getCatalogProto(ManagedCatalogClientImpl.scala:703)
# 	at com.databricks.sql.managedcatalog.client.ManagedCatalogClientImpl.getCatalog(ManagedCatalogClientImpl.scala:690)
# 	at com.databricks.sql.managedcatalog.ManagedCatalogCommon.$anonfun$getCatalogMetadata$5(ManagedCatalogCommon.scala:545)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.sql.managedcatalog.ManagedCatalogCommon.getCatalogMetadata(ManagedCatalogCommon.scala:542)
# 	at com.databricks.sql.managedcatalog.ProfiledManagedCatalog.$anonfun$getCatalogMetadata$1(ProfiledManagedCatalog.scala:156)
# 	at org.apache.spark.sql.catalyst.MetricKeyUtils$.measure(MetricKey.scala:3067)
# 	at com.databricks.sql.managedcatalog.ProfiledManagedCatalog.$anonfun$profile$1(ProfiledManagedCatalog.scala:80)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:146)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at com.databricks.sql.managedcatalog.ProfiledManagedCatalog.profile(ProfiledManagedCatalog.scala:79)
# 	at com.databricks.sql.managedcatalog.ProfiledManagedCatalog.getCatalogMetadata(ProfiledManagedCatalog.scala:156)
# 	at com.databricks.sql.managedcatalog.ManagedCatalogSessionCatalog.getCatalog(ManagedCatalogSessionCatalog.scala:1417)
# 	at org.apache.spark.sql.execution.datasources.v2.DataSourceV2Strategy.$anonfun$resolveNamespaceCollation$1(DataSourceV2Strategy.scala:131)
# 	at scala.Option.orElse(Option.scala:477)
# 	at org.apache.spark.sql.execution.datasources.v2.DataSourceV2Strategy.resolveNamespaceCollation(DataSourceV2Strategy.scala:127)
# 	at org.apache.spark.sql.execution.datasources.v2.DataSourceV2Strategy.apply(DataSourceV2Strategy.scala:912)
# 	at org.apache.spark.sql.catalyst.planning.QueryPlanner.$anonfun$plan$3(QueryPlanner.scala:109)
# 	at com.databricks.spark.util.MemoryTracker$.withThreadAllocatedBytes(MemoryTracker.scala:68)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.measureRule(QueryPlanningTracker.scala:509)
# 	at org.apache.spark.sql.catalyst.planning.QueryPlanner.$anonfun$plan$2(QueryPlanner.scala:109)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.planning.QueryPlanner.$anonfun$plan$1(QueryPlanner.scala:107)
# 	at scala.collection.Iterator$$anon$10.nextCur(Iterator.scala:604)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:618)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:611)
# 	at org.apache.spark.sql.catalyst.planning.QueryPlanner.plan(QueryPlanner.scala:148)
# 	at org.apache.spark.sql.execution.SparkStrategies.plan(SparkStrategies.scala:110)
# 	at org.apache.spark.sql.catalyst.planning.QueryPlanner.$anonfun$plan$6(QueryPlanner.scala:133)
# 	at scala.collection.IterableOnceOps.foldLeft(IterableOnce.scala:738)
# 	at scala.collection.IterableOnceOps.foldLeft$(IterableOnce.scala:732)
# 	at scala.collection.AbstractIterator.foldLeft(Iterator.scala:1313)
# 	at org.apache.spark.sql.catalyst.planning.QueryPlanner.$anonfun$plan$5(QueryPlanner.scala:130)
# 	at scala.collection.Iterator$$anon$10.nextCur(Iterator.scala:604)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:618)
# 	at org.apache.spark.sql.catalyst.planning.QueryPlanner.plan(QueryPlanner.scala:148)
# 	at org.apache.spark.sql.execution.SparkStrategies.plan(SparkStrategies.scala:110)
# 	at org.apache.spark.sql.execution.QueryExecution$.$anonfun$createSparkPlan$1(QueryExecution.scala:2203)
# 	at com.databricks.spark.util.MemoryTracker$.withThreadAllocatedBytes(MemoryTracker.scala:68)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.measureRule(QueryPlanningTracker.scala:509)
# 	at org.apache.spark.sql.execution.QueryExecution$.createSparkPlan(QueryExecution.scala:2203)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazySparkPlan$2(QueryExecution.scala:1234)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:1256)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$8(QueryExecution.scala:1417)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withExecutionPhase$1(SQLExecution.scala:382)
# 	at com.databricks.util.TracingSpanUtils$.withTracing(TracingSpanUtils.scala:251)
# 	at com.databricks.spark.util.DatabricksTracingHelper.withSpan(DatabricksSparkTracingHelper.scala:290)
# 	at com.databricks.spark.util.DBRTracing$.withSpan(DBRTracing.scala:87)
# 	at org.apache.spark.sql.execution.SQLExecution$.withExecutionPhase(SQLExecution.scala:363)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$7(QueryExecution.scala:1417)
# 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:2268)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$5(QueryExecution.scala:1408)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$4(QueryExecution.scala:1405)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$3(QueryExecution.scala:1405)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$2(QueryExecution.scala:1404)
# 	at com.databricks.sql.history.ultron.PredictionBackendBatching$.$anonfun$withBatchedUpdates$1(ObservationBuffer.scala:484)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at com.databricks.sql.history.ultron.PredictionBackendBatching$.withBatchedUpdates(ObservationBuffer.scala:484)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$3(QueryExecution.scala:1384)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.localBlock$1(QueryExecution.scala:1383)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$5(QueryExecution.scala:1395)
# 	at com.databricks.unity.UCSManager$.withTemporaryScope(UCSManager.scala:168)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$4(QueryExecution.scala:1394)
# 	at org.apache.spark.sql.execution.QueryExecution$.$anonfun$runWithWrappers$2(QueryExecution.scala:2523)
# 	at org.apache.spark.sql.execution.QueryExecution$.org$apache$spark$sql$execution$QueryExecution$$runWithWrappers(QueryExecution.scala:2522)
# 	at org.apache.spark.sql.execution.QueryExecution.withQueryExecutionId(QueryExecution.scala:1395)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$1(QueryExecution.scala:1403)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.execution.QueryExecution.executePhase(QueryExecution.scala:1402)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhaseWithTracker$1(QueryExecution.scala:1436)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:297)
# 	at org.apache.spark.sql.execution.QueryExecution.executePhaseWithTracker(QueryExecution.scala:1436)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazySparkPlan$1(QueryExecution.scala:1231)
# 	at scala.util.Try$.apply(Try.scala:217)
# 	at org.apache.spark.util.Utils$.doTryWithCallerStacktrace(Utils.scala:1797)
# 	at org.apache.spark.util.Utils$.getTryWithCallerStacktrace(Utils.scala:1847)
# 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:78)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$sparkPlan$1(QueryExecution.scala:1242)
# 	at org.apache.spark.sql.execution.QueryExecution.withAbortTransactionOnFailure(QueryExecution.scala:1792)
# 	at org.apache.spark.sql.execution.QueryExecution.sparkPlan(QueryExecution.scala:1242)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$28(SQLExecution.scala:1259)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:297)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$23(SQLExecution.scala:1259)
# 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:111)
# 	at org.apache.spark.util.Utils$.getTryWithCallerStacktrace(Utils.scala:1847)
# 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:78)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executedPlan$1(QueryExecution.scala:1300)
# 	at org.apache.spark.sql.execution.QueryExecution.withAbortTransactionOnFailure(QueryExecution.scala:1792)
# 	at org.apache.spark.sql.execution.QueryExecution.executedPlan(QueryExecution.scala:1300)
# 	at org.apache.spark.sql.execution.ui.SQLAppStatusListener.getQueryProfileBuildParams(SQLAppStatusListener.scala:893)
# 	at org.apache.spark.sql.execution.ui.SQLAppStatusListener.onSQLUsageLogging(SQLAppStatusListener.scala:1002)
# 	at org.apache.spark.sql.execution.ui.SQLAppStatusListener.onOtherEvent(SQLAppStatusListener.scala:1102)
# 	at org.apache.spark.scheduler.SparkListenerBus.doPostEvent(SparkListenerBus.scala:108)
# 	at org.apache.spark.scheduler.SparkListenerBus.doPostEvent$(SparkListenerBus.scala:28)
# 	at org.apache.spark.scheduler.AsyncEventQueue.doPostEvent(AsyncEventQueue.scala:50)
# 	at org.apache.spark.scheduler.AsyncEventQueue.doPostEvent(AsyncEventQueue.scala:50)
# 	at org.apache.spark.util.ListenerBus.postToAll(ListenerBus.scala:219)
# 	at org.apache.spark.util.ListenerBus.postToAll$(ListenerBus.scala:183)
# 	at org.apache.spark.scheduler.AsyncEventQueue.super$postToAll(AsyncEventQueue.scala:195)
# 	at org.apache.spark.scheduler.AsyncEventQueue.$anonfun$dispatch$1(AsyncEventQueue.scala:195)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at org.apache.spark.scheduler.AsyncEventQueue.org$apache$spark$scheduler$AsyncEventQueue$$dispatch(AsyncEventQueue.scala:130)
# 	at org.apache.spark.scheduler.AsyncEventQueue$$anon$2.$anonfun$run$1(AsyncEventQueue.scala:120)
# 	at org.apache.spark.util.Utils$.tryOrStopSparkContext(Utils.scala:1669)
# 	at org.apache.spark.scheduler.AsyncEventQueue$$anon$2.run(AsyncEventQueue.scala:120)

# %%
# %sql
CREATE OR REPLACE VIEW workspace.learning.people AS
SELECT * FROM parquet.`/databricks-datasets/learning-spark-v2/people/people-10m.parquet/`
